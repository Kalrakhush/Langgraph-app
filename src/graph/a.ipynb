# %%
# src/graph/graph.py
from typing import Dict, Any
from langgraph.graph import StateGraph, END
from langsmith import traceable
from .nodes import GraphNodes, GraphState

class AIProcessingGraph:
    """Main LangGraph implementation for the AI pipeline."""
    
    def __init__(self):
        self.nodes = GraphNodes()
        self.graph = self._build_graph()


    
    def _build_graph(self) -> StateGraph:
        """Build the LangGraph workflow."""
        
        # Define the workflow
        workflow = StateGraph(GraphState)
        
        # Add nodes
        workflow.add_node("classify_intent", self.nodes.classify_intent)
        workflow.add_node("fetch_weather", self.nodes.fetch_weather)
        workflow.add_node("retrieve_from_pdf", self.nodes.retrieve_from_pdf)
        workflow.add_node("generate_response", self.nodes.generate_response)
        
        # Set entry point
        workflow.set_entry_point("classify_intent")
        
        # Add conditional edges
        workflow.add_conditional_edges(
            "classify_intent",
            self._route_by_intent,
            {
                "weather": "fetch_weather",
                "pdf": "retrieve_from_pdf"
            }
        )
        
        # Add edges to response generation
        workflow.add_edge("fetch_weather", "generate_response")
        workflow.add_edge("retrieve_from_pdf", "generate_response")
        
        # Add final edge
        workflow.add_edge("generate_response", END)
        
        return workflow.compile()
    
    def _route_by_intent(self, state: GraphState) -> str:
        """Route based on classified intent."""
        return state.intent
    
    @traceable(name="ai_pipeline_process")
    def process_query(self, query: str) -> Dict[str, Any]:
        """
        Process a user query through the AI pipeline.
        
        Args:
            query: User query string
            
        Returns:
            Processing results with response and metadata
        """
        try:
            # Initialize state
            initial_state = GraphState()
            initial_state.query = query
            
            # Run the graph
            result = self.graph.invoke(initial_state)
            
            return {
                "query": query,
                "intent": result.intent,
                "response": result.final_response,
                "weather_data": result.weather_data,
                "retrieved_docs_count": len(result.retrieved_docs),
                "metadata": result.metadata
            }
            
        except Exception as e:
            print(f"Error processing query: {e}")
            return {
                "query": query,
                "intent": "unknown",
                "response": "I encountered an error while processing your request. Please try again.",
                "weather_data": {},
                "retrieved_docs_count": 0,
                "metadata": {"error": str(e)}
            }
    
    def get_drawable_graph(self):
        """Return a drawable graph object for visualization."""
        return self.graph.get_graph()
        
    async def aprocess_query(self, query: str) -> Dict[str, Any]:
        """
        Async version of process_query.
        
        Args:
            query: User query string
            
        Returns:
            Processing results with response and metadata
        """
        try:
            # Initialize state
            initial_state = GraphState()
            initial_state.query = query
            
            # Run the graph asynchronously
            result = await self.graph.ainvoke(initial_state)
            
            return {
                "query": query,
                "intent": result.intent,
                "response": result.final_response,
                "weather_data": result.weather_data,
                "retrieved_docs_count": len(result.retrieved_docs),
                "metadata": result.metadata
            }
            
        except Exception as e:
            print(f"Error processing query: {e}")
            return {
                "query": query,
                "intent": "unknown",
                "response": "I encountered an error while processing your request. Please try again.",
                "weather_data": {},
                "retrieved_docs_count": 0,
                "metadata": {"error": str(e)}
            }
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[6], line 5
#       3 from langgraph.graph import StateGraph, END
#       4 from langsmith import traceable
# ----> 5 from .nodes import GraphNodes, GraphState
#       7 class AIProcessingGraph:
#       8     """Main LangGraph implementation for the AI pipeline."""
#
# ImportError: attempted relative import with no known parent package

# %%
# !pip install langchain-groq
# Out:
# Collecting langchain-groq
#   Downloading langchain_groq-0.3.6-py3-none-any.whl.metadata (2.6 kB)
# Requirement already satisfied: langchain-core<1.0.0,>=0.3.68 in c:\users\khush\miniconda3\envs\myenv\lib\site-packages (from langchain-groq) (0.3.72)
# Collecting groq<1,>=0.29.0 (from langchain-groq)
#   Downloading groq-0.30.0-py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: anyio<5,>=3.5.0 in c:\users\khush\miniconda3\envs\myenv\lib\site-packages (from groq<1,>=0.29.0->langchain-groq) (4.8.0)
# Requirement already satisfied: distro<2,>=1.7.0 in c:\users\khush\miniconda3\envs\myenv\lib\site-packages (from groq<1,>=0.29.0->langchain-groq) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in c:\users\khush\miniconda3\envs\myenv\lib\site-packages (from groq<1,>=0.29.0->langchain-groq) (0.27.2)
# Requirement already satisfied: pydantic<3,>=1.9.0 in c:\users\khush\miniconda3\envs\myenv\lib\site-packages (from groq<1,>=0.29.0->langchain-groq) (2.10.6)
# Requirement already satisfied: sniffio in c:\users\khush\miniconda3\envs\myenv\lib\site-packages (from groq<1,>=0.29.0->langchain-groq) (1.3.1)
# Requirement already satisfied: typing-extensions<5,>=4.10 in c:\users\khush\miniconda3\envs\myenv\lib\site-packages (from groq<1,>=0.29.0->langchain-groq) (4.12.2)
# Requirement already satisfied: langsmith>=0.3.45 in c:\users\khush\miniconda3\envs\myenv\lib\site-packages (from langchain-core<1.0.0,>=0.3.68->langchain-groq) (0.4.10)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\users\khush\miniconda3\envs\myenv\lib\site-packages (from langchain-core<1.0.0,>=0.3.68->langchain-groq) (9.0.0)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in c:\users\khush\miniconda3\envs\myenv\lib\site-packages (from langchain-core<1.0.0,>=0.3.68->langchain-groq) (1.33)
# Requirement already satisfied: PyYAML>=5.3 in c:\users\khush\miniconda3\envs\myenv\lib\site-packages (from langchain-core<1.0.0,>=0.3.68->langchain-groq) (6.0.2)
# Requirement already satisfied: packaging>=23.2 in c:\users\khush\miniconda3\envs\myenv\lib\site-packages (from langchain-core<1.0.0,>=0.3.68->langchain-groq) (24.2)
# Requirement already satisfied: exceptiongroup>=1.0.2 in c:\users\khush\miniconda3\envs\myenv\lib\site-packages (from anyio<5,>=3.5.0->groq<1,>=0.29.0->langchain-groq) (1.2.2)
# Requirement already satisfied: idna>=2.8 in c:\users\khush\miniconda3\envs\myenv\lib\site-packages (from anyio<5,>=3.5.0->groq<1,>=0.29.0->langchain-groq) (3.10)
# Requirement already satisfied: certifi in c:\users\khush\miniconda3\envs\myenv\lib\site-packages (from httpx<1,>=0.23.0->groq<1,>=0.29.0->langchain-groq) (2025.1.31)
# Requirement already satisfied: httpcore==1.* in c:\users\khush\miniconda3\envs\myenv\lib\site-packages (from httpx<1,>=0.23.0->groq<1,>=0.29.0->langchain-groq) (1.0.7)
# Requirement already satisfied: h11<0.15,>=0.13 in c:\users\khush\miniconda3\envs\myenv\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->groq<1,>=0.29.0->langchain-groq) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\khush\miniconda3\envs\myenv\lib\site-packages (from jsonpatch<2.0,>=1.33->langchain-core<1.0.0,>=0.3.68->langchain-groq) (3.0.0)
# Requirement already satisfied: orjson>=3.9.14 in c:\users\khush\miniconda3\envs\myenv\lib\site-packages (from langsmith>=0.3.45->langchain-core<1.0.0,>=0.3.68->langchain-groq) (3.10.15)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\users\khush\miniconda3\envs\myenv\lib\site-packages (from langsmith>=0.3.45->langchain-core<1.0.0,>=0.3.68->langchain-groq) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in c:\users\khush\miniconda3\envs\myenv\lib\site-packages (from langsmith>=0.3.45->langchain-core<1.0.0,>=0.3.68->langchain-groq) (2.32.3)
# Requirement already satisfied: zstandard>=0.23.0 in c:\users\khush\miniconda3\envs\myenv\lib\site-packages (from langsmith>=0.3.45->langchain-core<1.0.0,>=0.3.68->langchain-groq) (0.23.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\khush\miniconda3\envs\myenv\lib\site-packages (from pydantic<3,>=1.9.0->groq<1,>=0.29.0->langchain-groq) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in c:\users\khush\miniconda3\envs\myenv\lib\site-packages (from pydantic<3,>=1.9.0->groq<1,>=0.29.0->langchain-groq) (2.27.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\khush\miniconda3\envs\myenv\lib\site-packages (from requests>=2.0.0->langsmith>=0.3.45->langchain-core<1.0.0,>=0.3.68->langchain-groq) (3.4.1)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\khush\miniconda3\envs\myenv\lib\site-packages (from requests>=2.0.0->langsmith>=0.3.45->langchain-core<1.0.0,>=0.3.68->langchain-groq) (2.3.0)
# Downloading langchain_groq-0.3.6-py3-none-any.whl (16 kB)
# Downloading groq-0.30.0-py3-none-any.whl (131 kB)
# Installing collected packages: groq, langchain-groq
# Successfully installed groq-0.30.0 langchain-groq-0.3.6

# %%
from IPython.display import display
from src.graph.graph import AIProcessingGraph

# Instantiate your graph
graph_instance = AIProcessingGraph()

# Get the drawable graph
dot_graph = graph_instance.get_drawable_graph()

# Display using IPython
display(dot_graph.draw())
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 2
#       1 from IPython.display import display
# ----> 2 from src.graph.graph import AIProcessingGraph
#       4 # Instantiate your graph
#       5 graph_instance = AIProcessingGraph()
#
# ModuleNotFoundError: No module named 'src'
